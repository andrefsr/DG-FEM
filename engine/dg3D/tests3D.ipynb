# %%
import numpy as np
import matplotlib.pyplot as plt
import Nodes3D as Nodes

#### Testar nós no tetraedro 3D

N = 5

x, y, z = Nodes.Nodes3D(N)
r, s, t = Nodes.xyztorst(x, y, z)

# %%
### testar número de condição da matriz de Vandermonde
